# %%
import os
import cv2
import random
import numpy as np
from glob import glob
from PIL import Image, ImageOps
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator 
from tensorflow.keras.utils import to_categorical, plot_model
from tensorflow.keras import models, layers, regularizers

# %%
model = models.load_model('./model/MIRNetH3.h5', compile=False)

# %%
def plot_results(images, titles, figure_size=(12, 12)):
    fig = plt.figure(figsize=figure_size)
    for i in range(len(images)):
        fig.add_subplot(1, len(images), i + 1).set_title(titles[i])
        _ = plt.imshow(images[i])
        plt.axis("off")
    plt.show()


def infer(original_image):
    image = keras.preprocessing.image.img_to_array(original_image)
    image = image.astype("float32") / 255.0
    image = np.expand_dims(image, axis=0)
    output = model.predict(image)
    output_image = output[0] * 255.0
    output_image = output_image.clip(0, 255)
    output_image = output_image.reshape(
        (np.shape(output_image)[0], np.shape(output_image)[1], 3)
    )
    output_image = Image.fromarray(np.uint8(output_image))
    original_image = Image.fromarray(np.uint8(original_image))
    return output_image

# %%
originial_omage = Image.open(val_generator)
enhanced_image = infer(original_image)
enhanced_image = enhanced_image.save("geeks.jpg")

# %% [markdown]
# ### Angry

# %%
import glob
dataset = glob.glob('./test/angry/*.jpg')

for img_id, img_path in enumerate(dataset):
    original_image = Image.open(img_path)
    enhanced_image = infer(original_image)
    enhanced_image.save(img_path)
# Out:
# ...
# 1/1 [==============================] - 0s 262ms/step

# %% [markdown]
# ### Disgust

# %%
import glob
dataset = glob.glob('./test/disgust/*.jpg')

for img_id, img_path in enumerate(dataset):
    original_image = Image.open(img_path)
    enhanced_image = infer(original_image)
    enhanced_image.save(img_path)
# Out:
# ...
# 1/1 [==============================] - 0s 141ms/step

# %% [markdown]
# ### Fear

# %%
import glob
dataset = glob.glob('./test/fear/*.jpg')

for img_id, img_path in enumerate(dataset):
    original_image = Image.open(img_path)
    enhanced_image = infer(original_image)
    enhanced_image.save(img_path)
# Out:
# ...
# 1/1 [==============================] - 0s 156ms/step

# %% [markdown]
# ### Happy

# %%
import glob
dataset = glob.glob('./test/happy/*.jpg')

for img_id, img_path in enumerate(dataset):
    original_image = Image.open(img_path)
    enhanced_image = infer(original_image)
    enhanced_image.save(img_path)
# Out:
# ...
# 1/1 [==============================] - 0s 491ms/step
# ...
# ...
# 1/1 [==============================] - 1s 571ms/step

# %% [markdown]
# ### Neutral

# %%
import glob
dataset = glob.glob('./test/neutral/*.jpg')

for img_id, img_path in enumerate(dataset):
    original_image = Image.open(img_path)
    enhanced_image = infer(original_image)
    enhanced_image.save(img_path)
# Out:
# ...
# 1/1 [==============================] - 0s 234ms/step
# ...
# ...
# 1/1 [==============================] - 0s 246ms/step

# %% [markdown]
# ### Sad

# %%
import glob
dataset = glob.glob('./test/sad/*.jpg')

for img_id, img_path in enumerate(dataset):
    original_image = Image.open(img_path)
    enhanced_image = infer(original_image)
    enhanced_image.save(img_path)
# Out:
# ...
# 1/1 [==============================] - 0s 207ms/step
# ...
# ...
# 1/1 [==============================] - 0s 225ms/step

# %% [markdown]
# ### Surprise

# %%
import glob
dataset = glob.glob('./test/surprise/*.jpg')

for img_id, img_path in enumerate(dataset):
    original_image = Image.open(img_path)
    enhanced_image = infer(original_image)
    enhanced_image.save(img_path)
# Out:
# ...
# 1/1 [==============================] - 0s 229ms/step
